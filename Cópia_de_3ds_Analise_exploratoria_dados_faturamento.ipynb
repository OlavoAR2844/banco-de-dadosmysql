# %% [markdown]
# <a href="https://colab.research.google.com/github/OlavoAR2844/banco-de-dadosmysql/blob/main/C%C3%B3pia_de_3ds_Analise_exploratoria_dados_faturamento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📊 **ANÁLISE EXPLORATÓRIA DE DADOS DE FATURAMENTO**
#
# ⚠️ATENÇÃO!!!⚠️ FAÇA UMA CÓPIA DESTE ARQUIVO NO SEU GOOGLE DRIVE ANTES DE COMEÇAR.
#
#
#  Clique no ícone de **Pasta** na lateral esquerda do Colab
#  e faça upload do arquivo **12-03 - Dashboard-base.xlsx**.

# %% [markdown]
# **Célula 1: Importação das Bibliotecas**
#
# Nesta etapa, carregamos o pandas para tratar os dados e o plotly para criar gráficos interativos e modernos.

# %%
# codigo #
# Garante que o motor de leitura de Excel esteja atualizado

# !pip install --upgrade openpyxl

# Importa bibliotecas necessárias do Python
import pandas as pd
import plotly.express as px
import plotly.io as pio

# Configura o gráfico para aparecer no Google Colab
pio.renderers.default = "colab"
print("✅ Bibliotecas prontas!")
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl) (2.0.0)
# ✅ Bibliotecas prontas!

# %% [markdown]
# **Célula 2: Carregamento da Base de Dados e Amostra**
#
# *Nota: Certifique-se de que o arquivo "12-03 - Dashboard-base.xlsx" foi carregado na pasta lateral do Colab.*

# %%
# codigo #


# Lendo a aba específica chamada 'Base'
nome_arquivo = '12-03 - Dashboard-base.xlsx'
df = pd.read_excel(nome_arquivo, sheet_name='Base')

print("Amostra dos Dados (Primeiras 5 linhas):")
df.head()
# Out:
# Amostra dos Dados (Primeiras 5 linhas):
# /usr/local/lib/python3.12/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning:
#
# Unknown extension is not supported and will be removed
#         Data   Ano  Mês Vendedor          Cliente        Região Produto  Valor
# 0 2019-01-01  2019  jan    Paulo  Thamires Bastos       Sudeste  Python    450
# 1 2019-01-01  2019  jan    Paulo  Jessika Mineiro  Centro-Oeste   Excel    500
# 2 2019-01-02  2019  jan    Diego    Glenda Jalles         Norte     VBA    600
# 3 2019-01-02  2019  jan    Diego   Eugênio Mattos           Sul  Python    450
# 4 2019-01-02  2019  jan     Alon    Yasmine Gomes         Norte     VBA    600

# %% [markdown]
# **Célula 3: Estrutura da Base de Dados**
#
# Aqui verificamos os tipos de colunas e se há necessidade de ajustes (como converter a Data).

# %%
# código #

# Mostra a estrutura da base de dados

print("--- Informações da Estrutura ---")
print(df.info())

# Garantir que a coluna Data seja do tipo datetime
df['Data'] = pd.to_datetime(df['Data'])

print("\nValores nulos por coluna:")
print(df.isnull().sum())

# %% [markdown]
# **Célula 4: Resumo Estatístico**
#
# Uma visão geral sobre os valores financeiros da planilha.

# %%
#  codigo  #

# Resumo estatístico do faturamento (valor)
resumo = df['Valor'].describe().to_frame()
resumo.columns = ['Estatísticas de Faturamento']
resumo

# %% [markdown]
# **Célula 5: Gráfico 1 - Faturamento Total por Vendedor**
#
# Este gráfico de barras horizontais ajuda a identificar rapidamente quem são os melhores vendedores, similar ao dashboard original.

# %%
#  codigo  #
# Gráfico de Faturamento por Vendedor
vendas_vendedor = df.groupby('Vendedor')['Valor'].sum().reset_index().sort_values('Valor', ascending=True)

fig1 = px.bar(vendas_vendedor,
             x='Valor',
             y='Vendedor',
             orientation='h',
             title='Faturamento Total por Vendedor',
             text_auto='.2s',
             color='Valor',
             color_continuous_scale='Viridis')

fig1.update_layout(yaxis={'categoryorder':'total ascending'})
fig1.show()

# %% [markdown]
# **Célula 6: Gráfico 2 - Distribuição por Região**
#
# Um gráfico de rosca para entender a participação de cada mercado.

# %%
#  codigo  #

# Gráfico do Faturamento por Região
vendas_regiao = df.groupby('Região')['Valor'].sum().reset_index()

fig2 = px.pie(vendas_regiao,
             values='Valor',
             names='Região',
             title='Participação do Faturamento por Região',
             hole=0.5,
             color_discrete_sequence=px.colors.qualitative.Pastel)

fig2.update_traces(textinfo='percent+label')
fig2.show()

# %% [markdown]
# **Célula 7: Gráfico 3 - Evolução Mensal do Faturamento**
#
# Gráfico de linhas para visualizar a sazonalidade e o crescimento ao longo dos meses.

# %%
#   codigo  #** SAZONALIDADE são padrões repetitivos em períodos de tempo.





# Gráfico comparativo de faturamentos - 2019 a 2021

# Ordenação dos meses para o gráfico ficar cronológico
ordem_meses = ['jan', 'fev', 'mar', 'abr', 'mai', 'jun', 'jul', 'ago', 'set', 'out', 'nov', 'dez']

# Agrupamento por Ano e Mês
df_evolucao = df.groupby(['Ano', 'Mês'])['Valor'].sum().reset_index()
df_evolucao['Mês'] = pd.Categorical(df_evolucao['Mês'], categories=ordem_meses, ordered=True)
df_evolucao = df_evolucao.sort_values(['Ano', 'Mês'])

fig3 = px.line(df_evolucao,
              x='Mês',
              y='Valor',
              color='Ano',
              title='Evolução Mensal do Faturamento (Comparativo Anual)',
              markers=True,
              line_shape='linear')

fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="bfa903cc-a89b-4d94-b282-0ae88f2507e0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bfa903cc-a89b-4d94-b282-0ae88f2507e0")) {                    Plotly.newPlot(                        "bfa903cc-a89b-4d94-b282-0ae88f2507e0",                        [{"hovertemplate":"Ano=2019\u003cbr\u003eMês=%{x}\u003cbr\u003eValor=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2019","line":{"color":"#636efa","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"2019","orientation":"v","showlegend":true,"x":["jan","fev","mar","abr","mai","jun","jul","ago","set","out","nov","dez"],"xaxis":"x","y":[52650,39450,44050,43650,47400,43400,45550,50150,50850,52650,47950,46050],"yaxis":"y","type":"scatter"},{"hovertemplate":"Ano=2020\u003cbr\u003eMês=%{x}\u003cbr\u003eValor=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2020","line":{"color":"#EF553B","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"2020","orientation":"v","showlegend":true,"x":["jan","fev","mar","abr","mai","jun","jul","ago","set","out","nov","dez"],"xaxis":"x","y":[47500,42300,48750,42950,57050,48300,53500,50450,40700,42850,40200,56600],"yaxis":"y","type":"scatter"},{"hovertemplate":"Ano=2021\u003cbr\u003eMês=%{x}\u003cbr\u003eValor=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2021","line":{"color":"#00cc96","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"2021","orientation":"v","showlegend":true,"x":["jan","fev","mar","abr","mai","jun","jul","ago","set","out","nov","dez"],"xaxis":"x","y":[47200,47400,41400,45450,47600,43450,45350,42750,54350,46850,50050,49250],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556, ...

# %% [markdown]
# **Célula 8: Gráfico 4 - Faturamento por Produto e Região**
#
# Gráfico de histogramas para visualizar e comparar o faturamento por produto em cada região do país.

# %%
#   codigo #

# Gráfico de Faturamento por Produto e Região

px.histogram(df, x='Produto', y='Valor', color='Região', barmode='group', title='Faturamento por Produto e Região')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0ee36dc0-a7ed-435b-938f-9f864550c649" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0ee36dc0-a7ed-435b-938f-9f864550c649")) {                    Plotly.newPlot(                        "0ee36dc0-a7ed-435b-938f-9f864550c649",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Região=Sudeste\u003cbr\u003eProduto=%{x}\u003cbr\u003esum of Valor=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sudeste","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Sudeste","offsetgroup":"Sudeste","orientation":"v","showlegend":true,"x":["Python","Word","Word","Word","Power BI","Power BI","Excel","VBA","Power BI","Power BI","Power BI","Power BI","Power BI","VBA","Excel","VBA","PowerPoint","VBA","Excel","Power BI","Power BI","Power BI","Power BI","Excel","Python","Word","Power BI","Word","Word","Word","Word","Word","Word","Word","Word","Word","Word","Word","Power BI","Word","Word","Word","Word","Word","Word","Word","Python","Word","Word","Power BI","Word","Word","Word","Word","Python","Power BI","Word","Word","Excel","VBA","VBA","Excel","Excel","VBA","VBA","Python","Python","Word","Word","Power BI","Word","Word","Word","Power BI","VBA","VBA","VBA","VBA","VBA","Excel","VBA","Excel","VBA","Power BI","Python","Python","VBA","Excel","VBA","Excel","Excel","VBA","VBA","Power BI","Power BI","Python","VBA","Python","Excel","Excel","Excel","Excel","Excel","Excel","VBA","Power BI","Power BI","VBA","Python","Excel","Power BI","VBA","Excel","Excel","Power BI","VBA","VBA","Excel","VBA","Excel","Excel","Excel","Python","VBA","Word","Excel","Python","Python","VBA","Word","Word","VBA","Excel","Power BI","VBA","VBA","Power BI","VBA","Excel","Excel","Excel","VBA","VBA","VBA","Python","Power BI","Power BI","VBA","Power BI","Excel","VBA","VBA","Python","Python","Python","Excel","Python","VBA","VBA","VBA","Power BI","VBA","Word","Word","Python","Word","Word","Word","Word","Word","Word","Word","Power BI","Word","Python","Word","Excel","VBA","Power BI","Excel","Excel","Excel","Python","Excel","Excel","VBA","Excel","VBA","Python","VBA","Excel","Python","Python","Excel","VBA","Python","Power BI","PowerPoint","VBA","Excel","PowerPoint","Excel","VBA","Python","VBA","Excel","VBA","Python","VBA","VBA","Power BI","VBA","Excel","VBA","VBA","Excel","VBA","VBA","VBA","Excel","Power BI","VBA","VBA","VBA","Python","Excel","VBA","Python","VBA","PowerPoint","Excel","VBA","VBA","PowerPoint","PowerPoint","VBA","VBA","PowerPoint","PowerPoint","PowerPoint","PowerPoint","PowerPoint","VBA","Python","PowerPoint","PowerPoint","VBA","Python","Excel","Python","Power BI","VBA","VBA","PowerPoint","VBA","VBA","Power BI","VBA","VBA","Python","Excel","VBA","Python","VBA","Word","Word","Word","Word","Word","Word","Word","Power BI","Word","Word","VBA","VBA","VBA","Power BI","VBA","Power BI","Excel","Python","VBA","Power BI","Python","Excel","VBA","Python","VBA","Excel","VBA","VBA","Python","Excel","VBA","Excel","VBA","VBA","Excel","Excel","VBA","Excel","Excel","Power BI","Power BI","Excel","VBA","VBA","Excel","VBA","Excel","VBA","Power BI","VBA","Excel","Power BI","Excel","Python","Python","Excel","VBA","VBA","VBA","PowerPoint","PowerPoint","Excel","PowerPoint","VBA","PowerPoint","VBA","VBA","VBA","VBA","PowerPoint","VBA","Excel","PowerPoint","Excel","VBA","PowerPoint","Excel","VBA","VBA","PowerPoint","VBA","VBA","Excel","VBA","VBA","VBA","VBA","VBA","Excel","VBA","Excel","VBA","PowerPoint","PowerPoint","Python","Excel","Python","VBA","VBA","VBA","VBA","VBA","Excel","VBA","Excel","VBA","VBA","VBA","Power BI","VBA","Excel","VBA","VBA","Power BI","Excel","Excel","VBA","Python","VBA","Excel","VBA","Power BI","Power BI","Power ...

# %% [markdown]
# ***😃A análise exploratória de dados está concluída!***
